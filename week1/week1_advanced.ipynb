# %% [markdown]
# # 1주차 심화 과제
# - MNIST 데이터셋 다중 분류
#
# - 구현 환경: 로컬 환경 rtx 4060 gpu만 사용하여 진행.
#
# - python version: 3.9.21
#
# - torch version: 2.2.1
#
# - 전체 코드 작동 시간: 30분 정도
#
# - 기본 과제와의 차별점
#
#     1) activation: Relu와 LeakyRelu, Sigmoid 비교
#     2) optimizer: SGD, Adam 비교
#     3) Dropout: 여부 비교
#
# - 즉, 1번, 2번, 3번 조합을 비교하여 열 두번의 실험 세트를 시도하여 결과를 비교하고 모두 플로팅 해볼 예정입니다.

# %% [markdown]
# ## [MY CODE] : HyperParameters
#
# - 해당 노트 전체에서 사용되는 하이퍼 파라미터, 혹은 주요 변수를 모아두었습니다.

# %%
import torch
import numpy as np
random_state = 42
device = "cuda" if torch.cuda.is_available else "cpu"
batch_size = 256
n_dim = 1024
lr = 1e-3
n_epochs = 50

# %% [markdown]
# ## [MY CODE] Load Dataset
#
# - 데이터셋을 로드하는 코드 cell 입니다.
#
# - train, val, test 데이터셋을 구성하여 훈련 중간 val로 점검을 하며 추후 테스트 데이터셋으로 마지막 metric을 찍어볼 예정입니다.
#
# - train 개수: 50000, val 개수: 8000, val 개수: 2000
#
# - shape에서 채널이 3인 것을 확인했습니다. 따라서, 이에 따라 파라미터도 매우 많아질 것을 예상할 수 있습니다.
#
# - 그리고 transform은 추후에 dataset을 만들 때 사용할 예정입니다.

# %%
from sklearn.model_selection import train_test_split 
import torchvision

trainset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
)
testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
)

test_size= 0.2
x_train = trainset.data
y_train = trainset.targets
x_test = testset.data
y_test = testset.targets
x_val, x_test, y_val, y_test = train_test_split(
    x_test, 
    y_test, 
    test_size=test_size,
    random_state=random_state
)
# Check Dataset Shape
print(f"Train Dataset Shape:\nx_train:{x_train.shape}, y_train:{len(y_train)}", end="\n\n")
print(f"Val Dataset Shape:\nx_val:{x_val.shape}, y_val:{len(y_val)}", end="\n\n")
print(f"Test Dataset Shape:\nx_test:{x_test.shape}, y_test:{len(y_test)}", end="\n\n")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train Dataset Shape:
# x_train:(50000, 32, 32, 3), y_train:50000
#
# Val Dataset Shape:
# x_val:(8000, 32, 32, 3), y_val:8000
#
# Test Dataset Shape:
# x_test:(2000, 32, 32, 3), y_test:2000

# %% [markdown]
# ## [MY CODE] Check Label Distribution
#
# - train, val, test의 라벨 분포도 입니다.
#
# - 치우친 데이터 없이 모두 고르게 되어 있습니다. 다중분류 상황에서 문제가 되는 라벨 불균형을 고려하지 않을 예정입니다.
#
# - 라벨의 수는 0~9까지 10입니다. 따라서 다중 모델의 최종 layer의 차원 수는 10입니다.
#
# - train과 다르게 test와 val이 0.1로 딱 떨어지지 않는 것은 train_test_split을 했기 때문입니다.

# %%
import pandas as pd
df = [
    pd.Series(label)
    .value_counts(normalize=True)
    .sort_index(ascending=True)
        for label in [y_train, y_val, y_test]
]
df = pd.concat(df, axis=1)
df.columns = ['train', 'val', 'test'] 
df
# Out:
#    train       val    test
# 0    0.1  0.101625  0.0935
# 1    0.1  0.101375  0.0945
# 2    0.1  0.099875  0.1005
# 3    0.1  0.100250  0.0990
# 4    0.1  0.102375  0.0905
# 5    0.1  0.101125  0.0955
# 6    0.1  0.098375  0.1065
# 7    0.1  0.096750  0.1130
# 8    0.1  0.099625  0.1015
# 9    0.1  0.098625  0.1055

# %% [markdown]
# ## [MY CODE] Check Label Image
#
# - train, val, test를 모두 검증하기 위하여 코드를 조금 수정하여 num을 입력하면 해당 샘플의 이미지와 라벨을 출력합니다.
#
# - 채널이 3개이기 때문에 컬러 이미지가 출력됩니다.

# %%
from matplotlib import pyplot as plt

def check_data(num, *args):
    for i, (sort, x, y) in enumerate(args):
        plt.subplot(1,len(args),i+1)
        plt.imshow(x[num], cmap='gray')
        plt.title(f"{sort} Label: {y[num]}")
        plt.axis('off')

# 몇 번째 샘플을 보여줄 것인지 결정하는 인자
num=0
check_data(
    num,
    ("train", x_train, y_train), 
    ("val", x_val, y_val), 
    ("test", x_test, y_test)
)

# %% [markdown]
# ## [MY CODE] Make Torch Dataset
#
# - torch dataset을 구성하여 dataloader에 올리는 것을 기반으로 하였습니다.
# - 또한 transform 과정에서 데이터 전처리에 해당하는 표준화를 수행하였습니다.

# %% [markdown]
# ## [FEEDBACK] 표준화 과정
# - 공식문서에서 3채널의 평균과 표준편차를 모두 0.5로 하드코딩한 채로 진행하는 것을 권하였습니다.
#
# - https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
#
# - 그런데 표준화를 한다는 것은 평균을 뺀 다음 표준편차로 나누는 것인데 어떻게 0.5, 0.5, 0.5가 나오는지 의문이 듭니다.
#
# - 그래서 저는 직접 평균, 표준편차를 구해봤는데, 학습이 전혀 되지 않았습니다.
#
# - 아래는 학습 로그를 캡처한 것입니다.
#
# ![image.png](attachment:image.png)
#
#
# - 그래서 그냥 0.5로 평균 표준편차를 걸었습니다.

# %%
from torch.utils.data import Dataset
import numpy as np
import torchvision.transforms as transforms

class dastaset(Dataset):
    def __init__(self, x, y, transform=None):
        torch.manual_seed(random_state)
        self.x = x
        self.y = y
        self.transform = transform
        
    def __getitem__(self, idx):
        sample_x, sample_y = self.x[idx], self.y[idx]
        if self.transform:
            sample_x = self.transform(sample_x)
        return sample_x, sample_y
    
    def __len__(self):
        return len(self.x)
    
# 왜 각 채널의 평균과 표준편차를 0.5로 줘도 되는지 궁금합니다.
transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize(
            (0.5,0.5,0.5), 
            (0.5,0.5,0.5), 
            )
    ],  
)

dataset_dict = {name:dastaset(x,y, transform)
                    for name,x,y in [
                            ('train', x_train, y_train),
                            ('val', x_val, y_val),
                            ('test', x_test, y_test)
                        ]
                }   
print(f"Dataset Keys: {dataset_dict.keys()}", end='\n\n')
for name in dataset_dict.keys():
    print(f"{name} len: {len(dataset_dict[name])}", end='\n\n')
# Out:
# Dataset Keys: dict_keys(['train', 'val', 'test'])
#
# train len: 50000
#
# val len: 8000
#
# test len: 2000

# %% [markdown]
# ## [MY CODE] Make Torch Dataloader
#
# - train, val, test 데이터 가지고 모두 데이터 로더를 구성하였습니다.
#
# - 코드를 간결하게 작성하기 위해 dict 형태로 묶었습니다.
#
# - val, test는 shuffle을 하면 안된다는 조건이 있었으므로, shuffle_map이라는 dict을 사용해 지정하였습니다.
#
# - 각각의 데이터로더가 잘 작동한는 것을 print를 통해 확인하였습니다.

# %%
from torch import nn
from itertools import product
input_dim = dataset_dict['train'][0][0].shape[0] * dataset_dict['train'][0][0].shape[1] * dataset_dict['train'][0][0].shape[2]

shuffle_map = {'train':True, 'val': False, 'test': False}

dataloader_dict = {name: torch.utils.data.DataLoader(
                            dataset_dict[name],
                            batch_size = batch_size,
                            shuffle=shuffle_map[name],
                        )
                        for name in dataset_dict.keys()
                    }

for name in dataloader_dict.keys():
    dataiter = iter(dataloader_dict[name])
    images, labels = next(dataiter)
    print(
        f"{name} input shape: {images.shape}",
        f"{name} output shape: {labels.shape}",
        f"{name} batch nums: {len(dataloader_dict[name])}",
        sep='\n',
        end='\n\n'
    )
# Out:
# train input shape: torch.Size([256, 3, 32, 32])
# train output shape: torch.Size([256])
# train batch nums: 196
#
# val input shape: torch.Size([256, 3, 32, 32])
# val output shape: torch.Size([256])
# val batch nums: 32
#
# test input shape: torch.Size([256, 3, 32, 32])
# test output shape: torch.Size([256])
# test batch nums: 8

# %% [markdown]
# ## [MY CODE] Build Model
#
# - 모델의 구조가 동적으로 변화하는 상황에서도 대응할 수 있도록 model config라는 dict을 따로 선언하였습니다.
#
# - 내부에서는 hidden layers와 final layer를 구분하여 model summary가 더 가시적으로 보이도록 하였습니다.
#
# - 현재 다중 분류 클래스스 개수가 10개인데, 마지막 출력이 1로 되어있는 것이 이상하다고 생각하여 10으로 정정했습니다.
#
# - 다중분류 상황에서 loss 함수는 crossentropy를 사용하고 마지막 계층의 활성화 함수는 softmax여야 하지만, crossentropy 함수가 softmax를 계산 과정으로 품고 있기 때문에, 마지막 계층의 활성화함수는 꺼두었습니다.
#
# - 참조: https://stackoverflow.com/questions/55675345/should-i-use-softmax-as-output-when-using-cross-entropy-loss-in-pytorch
#
# - 아래는 activation에 대하여 경우 3가지, dropout에 대하여 경우 2가지, optimizer에 대하여 경우 2가지해서 총 12가지의 경우의 수에 대하여 실험을 해보는 코드입니다.
#
# - 모델을 config를 통하여 동적으로 실행합니다.

# %% [markdown]
# ## [FEED BACK]
#
# - dropout은 활성화함수 앞에 있어야 하나요?
#
# - https://stackoverflow.com/questions/39691902/ordering-of-batch-normalization-and-dropout#answer-40295999

# %%
from itertools import product
activation_lst = [nn.ReLU(), nn.LeakyReLU(), nn.Sigmoid()]
dropout_lst = [True, False]
optimizer_lst = ['Adam', 'SGD']

class Model(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.hidden_layers = nn.ModuleDict() 
        for i, (name, (input_dim, output_dim, activation, flag)) in enumerate(config.items()):
            if i + 1 != len(config):
                self.hidden_layers[f"{name}_layer"] = nn.Linear(input_dim, output_dim)
                # flag가 True일 때에만 dropout이 삽입됩니다.
                # 이 때 dropout layer가 여기에 있는 게 맞나요?
                # 

                self.hidden_layers[f"{name}_activation"] = activation
                if flag:
                    self.hidden_layers[f"{name}_dropout"] = nn.Dropout(p=0.1)

        self.final_layer = nn.ModuleDict() 
        self.final_layer[f"{list(config.keys())[-1]}_layer"] = nn.Linear(list(config.values())[-1][0], list(config.values())[-1][1])

    def forward(self, x):
        x = x.flatten(start_dim=1)
        for layer in self.hidden_layers.values():
            x = layer(x)
        for layer in self.final_layer.values():
            x = layer(x)
        return x

# %% [markdown]
# ## [MY CODE] Start Train
#
# - train과 val 데이터로더를 통해 훈련을 하고 있습니다.
#
# - 특징1: loss를 계산할 때 배치당 loss로 평균을 내어서, validation 과정에서 도출 된 loss와 같은 기준선에서 비교가 가능하도록 scaling을 하였습니다.
#
# - 특징2: validation을 매 epoch이 아니라 5 epoch 마다 하여서, 추세를 확인하는 용도로 사용하였습니다.
#
# - 특징3: 다중분류이므로 accuracy와 f1_score를 같이 가져왔습니다. 이 때 sklearn 라이브러리를 활용하여 custom 구현에 의한 오류 발생 여지를 줄였습니다.

# %% [markdown]
# ## [FEEDBACK]
#
# - onehot encoding을 다중 분류 과정에서 해야 한다고 알고 있습니다.
#
# - 그러나 CrossEntropy는 정수 인코딩된 클래스를 요구받는다고 합니다.
#
# - onehot encoding을 안한 것이 metric을 저하시키진 않는지 궁금합니다.

# %% [markdown]
# ## [LOG] Train, Val Metric
#
# - 훈련 과정에서 5 epoch 마다의 metric을 모두 찍고 있습니다.
#
# - 12가지의 케이스에 대하여 모두 로그를 남깁니다.

# %%
from torch.optim import SGD, Adam
from sklearn.metrics import accuracy_score, f1_score

result_dict = {}
for i, (activation, dropout, optimizer_name) in enumerate(product(activation_lst, dropout_lst, optimizer_lst)):
  print(f"{i+1}/{len(list(product(activation_lst, dropout_lst, optimizer_lst)))} Case",
        f"활성화 함수: {activation}, Dropout 여부: {dropout}, optimizer: {optimizer_name}", sep='\n')
  
  model_config = {
      "layer1":(input_dim, n_dim, activation, dropout),
      "layer2":(n_dim, n_dim, activation, dropout),
      "final":(n_dim, 10, None, None)
  }

  model = Model(model_config)
  model = model.to(device)
  print(model)

  optimizer_dict = {
      'Adam': Adam(model.parameters(), lr=lr),
      'SGD': SGD(model.parameters(), lr=lr)
      }
  optimizer = optimizer_dict[optimizer_name]
  criterion = nn.CrossEntropyLoss()

  train_metric_dict = {'loss':[],'accuracy':[],'f1_score':[]}
  val_metric_dict = {'loss':[],'accuracy':[],'f1_score':[]}

  print('훈련 시작...')
  for epoch in range(n_epochs):
    total_loss_lst = []
    total_preds_lst=[]
    total_labels_lst=[]

    for inputs, labels in dataloader_dict['train']:
      model.train()
      model.zero_grad()
      inputs, labels = inputs.to(device), labels.to(device).long() 
      preds = model(inputs)
      loss = criterion(preds, labels)

      preds_labels = torch.max(preds, dim=1).indices.detach().cpu().numpy()
      total_preds_lst.extend(preds_labels)
      labels = labels.detach().cpu().numpy()
      total_labels_lst.extend(labels)

      loss.backward()
      optimizer.step()
      total_loss_lst.append(loss.item())
      
    accuracy = accuracy_score(preds_labels, labels)
    f1 = f1_score(preds_labels, labels, average='macro')
    total_loss = np.mean(total_loss_lst)
    
    train_metric_dict['loss'].append(total_loss)
    train_metric_dict['accuracy'].append(accuracy)
    train_metric_dict['f1_score'].append(f1)

    if (epoch+1) % 5 == 1:
      print(f"Train Epoch {epoch+1:3d} | Loss: {total_loss:.3f} | Accuracy: {accuracy:.3f} | F1_Score: {f1:.3f}")
      val_loss_lst = []
      val_preds_lst=[]
      val_labels_lst=[]

      for inputs, labels in dataloader_dict['val']:
        model.zero_grad()
        inputs, labels = inputs.to(device), labels.to(device).long() 

        with torch.no_grad():
          model.eval()
          preds = model(inputs)

        loss = criterion(preds, labels)
        preds_labels = torch.max(preds, dim=1).indices.detach().cpu().numpy()
        val_preds_lst.extend(preds_labels)
        labels = labels.detach().cpu().numpy()
        val_labels_lst.extend(labels)
        val_loss_lst.append(loss.item())
        
      accuracy = accuracy_score(val_preds_lst, val_labels_lst)
      f1 = f1_score(val_preds_lst, val_labels_lst, average='macro')
      val_loss = np.mean(val_loss_lst)

      val_metric_dict['loss'].append((epoch,val_loss))
      val_metric_dict['accuracy'].append((epoch,accuracy))
      val_metric_dict['f1_score'].append((epoch,f1))
      
      print(f"Val | Loss: {val_loss:.3f} | Accuracy: {accuracy:.3f} | F1_Score: {f1:.3f}", end='\n\n')
  result_dict[(activation, dropout, optimizer_name)] = {'train':train_metric_dict, 'val':val_metric_dict, 'model': model}
  print("-"*15,"\n")
# Out:
# 1/12 Case
# 활성화 함수: ReLU(), Dropout 여부: True, optimizer: Adam
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_dropout): Dropout(p=0.1, inplace=False)
#     (layer1_activation): ReLU()
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_dropout): Dropout(p=0.1, inplace=False)
#     (layer2_activation): ReLU()
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 1.647 | Accuracy: 0.487 | F1_Score: 0.460
# Val | Loss: 1.484 | Accuracy: 0.472 | F1_Score: 0.473
#
# Train Epoch   6 | Loss: 1.071 | Accuracy: 0.637 | F1_Score: 0.589
# Val | Loss: 1.329 | Accuracy: 0.547 | F1_Score: 0.545
#
# Train Epoch  11 | Loss: 0.711 | Accuracy: 0.662 | F1_Score: 0.638
# Val | Loss: 1.499 | Accuracy: 0.551 | F1_Score: 0.551
#
# Train Epoch  16 | Loss: 0.474 | Accuracy: 0.713 | F1_Score: 0.705
# Val | Loss: 1.772 | Accuracy: 0.551 | F1_Score: 0.549
#
# Train Epoch  21 | Loss: 0.338 | Accuracy: 0.825 | F1_Score: 0.831
# Val | Loss: 2.112 | Accuracy: 0.559 | F1_Score: 0.557
#
# Train Epoch  26 | Loss: 0.274 | Accuracy: 0.887 | F1_Score: 0.885
# Val | Loss: 2.321 | Accuracy: 0.550 | F1_Score: 0.551
#
# Train Epoch  31 | Loss: 0.237 | Accuracy: 0.887 | F1_Score: 0.868
# Val | Loss: 2.654 | Accuracy: 0.547 | F1_Score: 0.545
#
# Train Epoch  36 | Loss: 0.209 | Accuracy: 0.912 | F1_Score: 0.916
# Val | Loss: 2.764 | Accuracy: 0.556 | F1_Score: 0.557
#
# Train Epoch  41 | Loss: 0.191 | Accuracy: 0.900 | F1_Score: 0.890
# Val | Loss: 2.919 | Accuracy: 0.562 | F1_Score: 0.560
#
# Train Epoch  46 | Loss: 0.173 | Accuracy: 0.938 | F1_Score: 0.940
# Val | Loss: 3.117 | Accuracy: 0.552 | F1_Score: 0.551
#
# ---------------
#
# 2/12 Case
# 활성화 함수: ReLU(), Dropout 여부: True, optimizer: SGD
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_dropout): Dropout(p=0.1, inplace=False)
#     (layer1_activation): ReLU()
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_dropout): Dropout(p=0.1, inplace=False)
#     (layer2_activation): ReLU()
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 2.297 | Accuracy: 0.113 | F1_Score: 0.086
# Val | Loss: 2.288 | Accuracy: 0.153 | F1_Score: 0.113
#
# Train Epoch   6 | Loss: 2.208 | Accuracy: 0.250 | F1_Score: 0.196
# Val | Loss: 2.196 | Accuracy: 0.264 | F1_Score: 0.224
#
# Train Epoch  11 | Loss: 2.114 | Accuracy: 0.163 | F1_Score: 0.138
# Val | Loss: 2.102 | Accuracy: 0.278 | F1_Score: 0.235
#
# Train Epoch  16 | Loss: 2.038 | Accuracy: 0.350 | F1_Score: 0.291
# Val | Loss: 2.027 | Accuracy: 0.297 | F1_Score: 0.260
#
# Train Epoch  21 | Loss: 1.977 | Accuracy: 0.275 | F1_Score: 0.242
# Val | Loss: 1.966 | Accuracy: 0.315 | F1_Score: 0.283
#
# Train Epoch  26 | Loss: 1.925 | Accuracy: 0.350 | F1_Score: 0.323
# Val | Loss: 1.916 | Accuracy: 0.332 | F1_Score: 0.305
#
# Train Epoch  31 | Loss: 1.882 | Accuracy: 0.325 | F1_Score: 0.306
# Val | Loss: 1.874 | Accuracy: 0.345 | F1_Score: 0.322
#
# Train Epoch  36 | Loss: 1.847 | Accuracy: 0.438 | F1_Score: 0.372
# Val | Loss: 1.839 | Accuracy: 0.357 | F1_Score: 0.338
#
# Train Epoch  41 | Loss: 1.817 | Accuracy: 0.425 | F1_Score: 0.393
# Val | Loss: 1.808 | Accuracy: 0.367 | F1_Score: 0.351
#
# Train Epoch  46 | Loss: 1.789 | Accuracy: 0.350 | F1_Score: 0.327
# Val | Loss: 1.782 | Accuracy: 0.376 | F1_Score: 0.362
#
# ---------------
#
# 3/12 Case
# 활성화 함수: ReLU(), Dropout 여부: False, optimizer: Adam
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_activation): ReLU()
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_activation): ReLU()
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 1.639 | Accuracy: 0.500 | F1_Score: 0.492
# Val | Loss: 1.472 | Accuracy: 0.473 | F1_Score: 0.461
#
# Train Epoch   6 | Loss: 0.964 | Accuracy: 0.662 | F1_Score: 0.654
# Val | Loss: 1.365 | Accuracy: 0.542 | F1_Score: 0.538
#
# Train Epoch  11 | Loss: 0.482 | Accuracy: 0.713 | F1_Score: 0.721
# Val | Loss: 1.778 | Accuracy: 0.532 | F1_Score: 0.534
#
# Train Epoch  16 | Loss: 0.240 | Accuracy: 0.912 | F1_Score: 0.886
# Val | Loss: 2.421 | Accuracy: 0.548 | F1_Score: 0.548
#
# Train Epoch  21 | Loss: 0.171 | Accuracy: 0.912 | F1_Score: 0.912
# Val | Loss: 3.010 | Accuracy: 0.540 | F1_Score: 0.539
#
# Train Epoch  26 | Loss: 0.138 | Accuracy: 0.975 | F1_Score: 0.980
# Val | Loss: 3.393 | Accuracy: 0.543 | F1_Score: 0.541
#
# Train Epoch  31 | Loss: 0.113 | Accuracy: 0.963 | F1_Score: 0.966
# Val | Loss: 3.884 | Accuracy: 0.541 | F1_Score: 0.544
#
# Train Epoch  36 | Loss: 0.109 | Accuracy: 0.975 | F1_Score: 0.975
# Val | Loss: 4.220 | Accuracy: 0.541 | F1_Score: 0.540
#
# Train Epoch  41 | Loss: 0.114 | Accuracy: 0.963 | F1_Score: 0.953
# Val | Loss: 4.250 | Accuracy: 0.535 | F1_Score: 0.535
#
# Train Epoch  46 | Loss: 0.092 | Accuracy: 0.975 | F1_Score: 0.978
# Val | Loss: 4.779 | Accuracy: 0.538 | F1_Score: 0.538
#
# ---------------
#
# 4/12 Case
# 활성화 함수: ReLU(), Dropout 여부: False, optimizer: SGD
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_activation): ReLU()
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_activation): ReLU()
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 2.301 | Accuracy: 0.150 | F1_Score: 0.117
# Val | Loss: 2.292 | Accuracy: 0.153 | F1_Score: 0.116
#
# Train Epoch   6 | Loss: 2.212 | Accuracy: 0.263 | F1_Score: 0.199
# Val | Loss: 2.203 | Accuracy: 0.261 | F1_Score: 0.214
#
# Train Epoch  11 | Loss: 2.120 | Accuracy: 0.287 | F1_Score: 0.222
# Val | Loss: 2.111 | Accuracy: 0.275 | F1_Score: 0.230
#
# Train Epoch  16 | Loss: 2.042 | Accuracy: 0.263 | F1_Score: 0.212
# Val | Loss: 2.033 | Accuracy: 0.295 | F1_Score: 0.257
#
# Train Epoch  21 | Loss: 1.976 | Accuracy: 0.250 | F1_Score: 0.240
# Val | Loss: 1.968 | Accuracy: 0.315 | F1_Score: 0.281
#
# Train Epoch  26 | Loss: 1.920 | Accuracy: 0.388 | F1_Score: 0.355
# Val | Loss: 1.915 | Accuracy: 0.331 | F1_Score: 0.300
#
# Train Epoch  31 | Loss: 1.875 | Accuracy: 0.400 | F1_Score: 0.352
# Val | Loss: 1.870 | Accuracy: 0.346 | F1_Score: 0.321
#
# Train Epoch  36 | Loss: 1.837 | Accuracy: 0.312 | F1_Score: 0.269
# Val | Loss: 1.833 | Accuracy: 0.358 | F1_Score: 0.337
#
# Train Epoch  41 | Loss: 1.805 | Accuracy: 0.338 | F1_Score: 0.275
# Val | Loss: 1.802 | Accuracy: 0.368 | F1_Score: 0.351
#
# Train Epoch  46 | Loss: 1.778 | Accuracy: 0.300 | F1_Score: 0.307
# Val | Loss: 1.775 | Accuracy: 0.378 | F1_Score: 0.364
#
# ---------------
#
# 5/12 Case
# 활성화 함수: LeakyReLU(negative_slope=0.01), Dropout 여부: True, optimizer: Adam
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_dropout): Dropout(p=0.1, inplace=False)
#     (layer1_activation): LeakyReLU(negative_slope=0.01)
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_dropout): Dropout(p=0.1, inplace=False)
#     (layer2_activation): LeakyReLU(negative_slope=0.01)
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 1.645 | Accuracy: 0.438 | F1_Score: 0.395
# Val | Loss: 1.481 | Accuracy: 0.481 | F1_Score: 0.477
#
# Train Epoch   6 | Loss: 1.070 | Accuracy: 0.650 | F1_Score: 0.656
# Val | Loss: 1.339 | Accuracy: 0.547 | F1_Score: 0.546
#
# Train Epoch  11 | Loss: 0.704 | Accuracy: 0.800 | F1_Score: 0.796
# Val | Loss: 1.516 | Accuracy: 0.546 | F1_Score: 0.546
#
# Train Epoch  16 | Loss: 0.450 | Accuracy: 0.800 | F1_Score: 0.804
# Val | Loss: 1.832 | Accuracy: 0.550 | F1_Score: 0.548
#
# Train Epoch  21 | Loss: 0.320 | Accuracy: 0.838 | F1_Score: 0.813
# Val | Loss: 2.162 | Accuracy: 0.554 | F1_Score: 0.553
#
# Train Epoch  26 | Loss: 0.262 | Accuracy: 0.850 | F1_Score: 0.858
# Val | Loss: 2.364 | Accuracy: 0.558 | F1_Score: 0.557
#
# Train Epoch  31 | Loss: 0.242 | Accuracy: 0.900 | F1_Score: 0.884
# Val | Loss: 2.635 | Accuracy: 0.546 | F1_Score: 0.547
#
# Train Epoch  36 | Loss: 0.208 | Accuracy: 0.900 | F1_Score: 0.877
# Val | Loss: 2.881 | Accuracy: 0.545 | F1_Score: 0.546
#
# Train Epoch  41 | Loss: 0.199 | Accuracy: 0.863 | F1_Score: 0.864
# Val | Loss: 2.886 | Accuracy: 0.554 | F1_Score: 0.554
#
# Train Epoch  46 | Loss: 0.178 | Accuracy: 0.912 | F1_Score: 0.906
# Val | Loss: 3.201 | Accuracy: 0.556 | F1_Score: 0.556
#
# ---------------
#
# 6/12 Case
# 활성화 함수: LeakyReLU(negative_slope=0.01), Dropout 여부: True, optimizer: SGD
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_dropout): Dropout(p=0.1, inplace=False)
#     (layer1_activation): LeakyReLU(negative_slope=0.01)
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_dropout): Dropout(p=0.1, inplace=False)
#     (layer2_activation): LeakyReLU(negative_slope=0.01)
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 2.295 | Accuracy: 0.150 | F1_Score: 0.086
# Val | Loss: 2.284 | Accuracy: 0.178 | F1_Score: 0.128
#
# Train Epoch   6 | Loss: 2.200 | Accuracy: 0.200 | F1_Score: 0.172
# Val | Loss: 2.188 | Accuracy: 0.258 | F1_Score: 0.204
#
# Train Epoch  11 | Loss: 2.107 | Accuracy: 0.287 | F1_Score: 0.237
# Val | Loss: 2.095 | Accuracy: 0.277 | F1_Score: 0.227
#
# Train Epoch  16 | Loss: 2.031 | Accuracy: 0.300 | F1_Score: 0.253
# Val | Loss: 2.020 | Accuracy: 0.297 | F1_Score: 0.254
#
# Train Epoch  21 | Loss: 1.969 | Accuracy: 0.388 | F1_Score: 0.331
# Val | Loss: 1.960 | Accuracy: 0.317 | F1_Score: 0.279
#
# Train Epoch  26 | Loss: 1.920 | Accuracy: 0.263 | F1_Score: 0.262
# Val | Loss: 1.910 | Accuracy: 0.331 | F1_Score: 0.300
#
# Train Epoch  31 | Loss: 1.877 | Accuracy: 0.325 | F1_Score: 0.324
# Val | Loss: 1.869 | Accuracy: 0.345 | F1_Score: 0.320
#
# Train Epoch  36 | Loss: 1.842 | Accuracy: 0.400 | F1_Score: 0.373
# Val | Loss: 1.834 | Accuracy: 0.359 | F1_Score: 0.339
#
# Train Epoch  41 | Loss: 1.812 | Accuracy: 0.338 | F1_Score: 0.309
# Val | Loss: 1.805 | Accuracy: 0.368 | F1_Score: 0.351
#
# Train Epoch  46 | Loss: 1.785 | Accuracy: 0.375 | F1_Score: 0.353
# Val | Loss: 1.778 | Accuracy: 0.379 | F1_Score: 0.365
#
# ---------------
#
# 7/12 Case
# 활성화 함수: LeakyReLU(negative_slope=0.01), Dropout 여부: False, optimizer: Adam
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_activation): LeakyReLU(negative_slope=0.01)
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_activation): LeakyReLU(negative_slope=0.01)
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 1.635 | Accuracy: 0.425 | F1_Score: 0.414
# Val | Loss: 1.480 | Accuracy: 0.479 | F1_Score: 0.471
#
# Train Epoch   6 | Loss: 0.954 | Accuracy: 0.613 | F1_Score: 0.584
# Val | Loss: 1.382 | Accuracy: 0.540 | F1_Score: 0.533
#
# Train Epoch  11 | Loss: 0.468 | Accuracy: 0.775 | F1_Score: 0.695
# Val | Loss: 1.825 | Accuracy: 0.543 | F1_Score: 0.542
#
# Train Epoch  16 | Loss: 0.226 | Accuracy: 0.938 | F1_Score: 0.945
# Val | Loss: 2.510 | Accuracy: 0.547 | F1_Score: 0.547
#
# Train Epoch  21 | Loss: 0.156 | Accuracy: 0.938 | F1_Score: 0.932
# Val | Loss: 2.964 | Accuracy: 0.543 | F1_Score: 0.543
#
# Train Epoch  26 | Loss: 0.156 | Accuracy: 0.950 | F1_Score: 0.948
# Val | Loss: 3.519 | Accuracy: 0.541 | F1_Score: 0.541
#
# Train Epoch  31 | Loss: 0.126 | Accuracy: 0.975 | F1_Score: 0.971
# Val | Loss: 3.944 | Accuracy: 0.544 | F1_Score: 0.542
#
# Train Epoch  36 | Loss: 0.110 | Accuracy: 0.938 | F1_Score: 0.925
# Val | Loss: 4.291 | Accuracy: 0.544 | F1_Score: 0.544
#
# Train Epoch  41 | Loss: 0.097 | Accuracy: 0.988 | F1_Score: 0.990
# Val | Loss: 4.671 | Accuracy: 0.545 | F1_Score: 0.545
#
# Train Epoch  46 | Loss: 0.093 | Accuracy: 0.938 | F1_Score: 0.927
# Val | Loss: 4.855 | Accuracy: 0.543 | F1_Score: 0.543
#
# ---------------
#
# 8/12 Case
# 활성화 함수: LeakyReLU(negative_slope=0.01), Dropout 여부: False, optimizer: SGD
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_activation): LeakyReLU(negative_slope=0.01)
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_activation): LeakyReLU(negative_slope=0.01)
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 2.297 | Accuracy: 0.150 | F1_Score: 0.139
# Val | Loss: 2.287 | Accuracy: 0.159 | F1_Score: 0.122
#
# Train Epoch   6 | Loss: 2.202 | Accuracy: 0.225 | F1_Score: 0.209
# Val | Loss: 2.191 | Accuracy: 0.258 | F1_Score: 0.210
#
# Train Epoch  11 | Loss: 2.109 | Accuracy: 0.250 | F1_Score: 0.216
# Val | Loss: 2.100 | Accuracy: 0.275 | F1_Score: 0.232
#
# Train Epoch  16 | Loss: 2.034 | Accuracy: 0.300 | F1_Score: 0.256
# Val | Loss: 2.027 | Accuracy: 0.291 | F1_Score: 0.256
#
# Train Epoch  21 | Loss: 1.972 | Accuracy: 0.325 | F1_Score: 0.310
# Val | Loss: 1.967 | Accuracy: 0.316 | F1_Score: 0.286
#
# Train Epoch  26 | Loss: 1.920 | Accuracy: 0.388 | F1_Score: 0.287
# Val | Loss: 1.916 | Accuracy: 0.331 | F1_Score: 0.304
#
# Train Epoch  31 | Loss: 1.878 | Accuracy: 0.250 | F1_Score: 0.238
# Val | Loss: 1.874 | Accuracy: 0.342 | F1_Score: 0.321
#
# Train Epoch  36 | Loss: 1.841 | Accuracy: 0.375 | F1_Score: 0.365
# Val | Loss: 1.839 | Accuracy: 0.354 | F1_Score: 0.337
#
# Train Epoch  41 | Loss: 1.811 | Accuracy: 0.438 | F1_Score: 0.403
# Val | Loss: 1.809 | Accuracy: 0.365 | F1_Score: 0.350
#
# Train Epoch  46 | Loss: 1.784 | Accuracy: 0.375 | F1_Score: 0.313
# Val | Loss: 1.783 | Accuracy: 0.377 | F1_Score: 0.365
#
# ---------------
#
# 9/12 Case
# 활성화 함수: Sigmoid(), Dropout 여부: True, optimizer: Adam
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_dropout): Dropout(p=0.1, inplace=False)
#     (layer1_activation): Sigmoid()
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_dropout): Dropout(p=0.1, inplace=False)
#     (layer2_activation): Sigmoid()
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 1.802 | Accuracy: 0.438 | F1_Score: 0.415
# Val | Loss: 1.639 | Accuracy: 0.424 | F1_Score: 0.410
#
# Train Epoch   6 | Loss: 1.242 | Accuracy: 0.562 | F1_Score: 0.560
# Val | Loss: 1.416 | Accuracy: 0.508 | F1_Score: 0.501
#
# Train Epoch  11 | Loss: 0.915 | Accuracy: 0.775 | F1_Score: 0.773
# Val | Loss: 1.480 | Accuracy: 0.519 | F1_Score: 0.511
#
# Train Epoch  16 | Loss: 0.648 | Accuracy: 0.725 | F1_Score: 0.734
# Val | Loss: 1.632 | Accuracy: 0.525 | F1_Score: 0.526
#
# Train Epoch  21 | Loss: 0.463 | Accuracy: 0.775 | F1_Score: 0.772
# Val | Loss: 1.865 | Accuracy: 0.529 | F1_Score: 0.531
#
# Train Epoch  26 | Loss: 0.342 | Accuracy: 0.938 | F1_Score: 0.934
# Val | Loss: 2.083 | Accuracy: 0.517 | F1_Score: 0.521
#
# Train Epoch  31 | Loss: 0.267 | Accuracy: 0.863 | F1_Score: 0.870
# Val | Loss: 2.260 | Accuracy: 0.526 | F1_Score: 0.529
#
# Train Epoch  36 | Loss: 0.224 | Accuracy: 0.963 | F1_Score: 0.965
# Val | Loss: 2.405 | Accuracy: 0.524 | F1_Score: 0.525
#
# Train Epoch  41 | Loss: 0.180 | Accuracy: 0.950 | F1_Score: 0.956
# Val | Loss: 2.565 | Accuracy: 0.521 | F1_Score: 0.523
#
# Train Epoch  46 | Loss: 0.163 | Accuracy: 0.938 | F1_Score: 0.936
# Val | Loss: 2.612 | Accuracy: 0.523 | F1_Score: 0.526
#
# ---------------
#
# 10/12 Case
# 활성화 함수: Sigmoid(), Dropout 여부: True, optimizer: SGD
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_dropout): Dropout(p=0.1, inplace=False)
#     (layer1_activation): Sigmoid()
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_dropout): Dropout(p=0.1, inplace=False)
#     (layer2_activation): Sigmoid()
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 2.311 | Accuracy: 0.087 | F1_Score: 0.068
# Val | Loss: 2.303 | Accuracy: 0.112 | F1_Score: 0.040
#
# Train Epoch   6 | Loss: 2.300 | Accuracy: 0.087 | F1_Score: 0.061
# Val | Loss: 2.299 | Accuracy: 0.105 | F1_Score: 0.039
#
# Train Epoch  11 | Loss: 2.297 | Accuracy: 0.237 | F1_Score: 0.171
# Val | Loss: 2.296 | Accuracy: 0.136 | F1_Score: 0.068
#
# Train Epoch  16 | Loss: 2.293 | Accuracy: 0.175 | F1_Score: 0.108
# Val | Loss: 2.292 | Accuracy: 0.176 | F1_Score: 0.096
#
# Train Epoch  21 | Loss: 2.290 | Accuracy: 0.175 | F1_Score: 0.133
# Val | Loss: 2.289 | Accuracy: 0.197 | F1_Score: 0.120
#
# Train Epoch  26 | Loss: 2.285 | Accuracy: 0.212 | F1_Score: 0.169
# Val | Loss: 2.284 | Accuracy: 0.167 | F1_Score: 0.104
#
# Train Epoch  31 | Loss: 2.281 | Accuracy: 0.300 | F1_Score: 0.225
# Val | Loss: 2.279 | Accuracy: 0.221 | F1_Score: 0.161
#
# Train Epoch  36 | Loss: 2.275 | Accuracy: 0.263 | F1_Score: 0.144
# Val | Loss: 2.274 | Accuracy: 0.207 | F1_Score: 0.131
#
# Train Epoch  41 | Loss: 2.269 | Accuracy: 0.250 | F1_Score: 0.172
# Val | Loss: 2.267 | Accuracy: 0.244 | F1_Score: 0.192
#
# Train Epoch  46 | Loss: 2.261 | Accuracy: 0.175 | F1_Score: 0.106
# Val | Loss: 2.259 | Accuracy: 0.223 | F1_Score: 0.160
#
# ---------------
#
# 11/12 Case
# 활성화 함수: Sigmoid(), Dropout 여부: False, optimizer: Adam
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_activation): Sigmoid()
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_activation): Sigmoid()
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 1.776 | Accuracy: 0.550 | F1_Score: 0.481
# Val | Loss: 1.604 | Accuracy: 0.428 | F1_Score: 0.411
#
# Train Epoch   6 | Loss: 1.160 | Accuracy: 0.625 | F1_Score: 0.631
# Val | Loss: 1.388 | Accuracy: 0.515 | F1_Score: 0.501
#
# Train Epoch  11 | Loss: 0.703 | Accuracy: 0.738 | F1_Score: 0.697
# Val | Loss: 1.536 | Accuracy: 0.516 | F1_Score: 0.517
#
# Train Epoch  16 | Loss: 0.355 | Accuracy: 0.950 | F1_Score: 0.953
# Val | Loss: 2.015 | Accuracy: 0.505 | F1_Score: 0.507
#
# Train Epoch  21 | Loss: 0.196 | Accuracy: 0.963 | F1_Score: 0.960
# Val | Loss: 2.376 | Accuracy: 0.507 | F1_Score: 0.505
#
# Train Epoch  26 | Loss: 0.113 | Accuracy: 0.975 | F1_Score: 0.969
# Val | Loss: 2.743 | Accuracy: 0.500 | F1_Score: 0.501
#
# Train Epoch  31 | Loss: 0.102 | Accuracy: 0.975 | F1_Score: 0.980
# Val | Loss: 3.010 | Accuracy: 0.497 | F1_Score: 0.500
#
# Train Epoch  36 | Loss: 0.129 | Accuracy: 0.950 | F1_Score: 0.952
# Val | Loss: 3.136 | Accuracy: 0.497 | F1_Score: 0.498
#
# Train Epoch  41 | Loss: 0.091 | Accuracy: 0.975 | F1_Score: 0.971
# Val | Loss: 3.388 | Accuracy: 0.498 | F1_Score: 0.499
#
# Train Epoch  46 | Loss: 0.060 | Accuracy: 0.975 | F1_Score: 0.978
# Val | Loss: 3.643 | Accuracy: 0.493 | F1_Score: 0.498
#
# ---------------
#
# 12/12 Case
# 활성화 함수: Sigmoid(), Dropout 여부: False, optimizer: SGD
# Model(
#   (hidden_layers): ModuleDict(
#     (layer1_layer): Linear(in_features=3072, out_features=1024, bias=True)
#     (layer1_activation): Sigmoid()
#     (layer2_layer): Linear(in_features=1024, out_features=1024, bias=True)
#     (layer2_activation): Sigmoid()
#   )
#   (final_layer): ModuleDict(
#     (final_layer): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )
# 훈련 시작...
# Train Epoch   1 | Loss: 2.306 | Accuracy: 0.113 | F1_Score: 0.046
# Val | Loss: 2.302 | Accuracy: 0.124 | F1_Score: 0.061
#
# Train Epoch   6 | Loss: 2.299 | Accuracy: 0.188 | F1_Score: 0.113
# Val | Loss: 2.299 | Accuracy: 0.133 | F1_Score: 0.078
#
# Train Epoch  11 | Loss: 2.295 | Accuracy: 0.188 | F1_Score: 0.082
# Val | Loss: 2.295 | Accuracy: 0.150 | F1_Score: 0.085
#
# Train Epoch  16 | Loss: 2.292 | Accuracy: 0.150 | F1_Score: 0.118
# Val | Loss: 2.291 | Accuracy: 0.203 | F1_Score: 0.135
#
# Train Epoch  21 | Loss: 2.288 | Accuracy: 0.237 | F1_Score: 0.181
# Val | Loss: 2.287 | Accuracy: 0.211 | F1_Score: 0.175
#
# Train Epoch  26 | Loss: 2.283 | Accuracy: 0.225 | F1_Score: 0.135
# Val | Loss: 2.283 | Accuracy: 0.186 | F1_Score: 0.097
#
# Train Epoch  31 | Loss: 2.278 | Accuracy: 0.287 | F1_Score: 0.171
# Val | Loss: 2.277 | Accuracy: 0.179 | F1_Score: 0.113
#
# Train Epoch  36 | Loss: 2.272 | Accuracy: 0.225 | F1_Score: 0.152
# Val | Loss: 2.271 | Accuracy: 0.236 | F1_Score: 0.181
#
# Train Epoch  41 | Loss: 2.265 | Accuracy: 0.200 | F1_Score: 0.163
# Val | Loss: 2.264 | Accuracy: 0.231 | F1_Score: 0.185
#
# Train Epoch  46 | Loss: 2.257 | Accuracy: 0.163 | F1_Score: 0.119
# Val | Loss: 2.255 | Accuracy: 0.247 | F1_Score: 0.191
#
# ---------------

# %% [markdown]
# ## [MY CODE] Case Plotting
#
# 각 케이스에 대하여 모두 플로팅을 하여봅니다.
#
# - 결론1: Adam이 SGD보다 월등히 성능이 좋았습니다.
#
# - 결론2: Relu와 LeakyRelu가 Sigmoid보다 월등히 성능이 좋습니다.
#
# - 결론3: Dropout을 켠 것이 끈 것보다 전체적으로 약간 성능이 좋았습니다.
#
# - 결론4: 전반적으로 Adam optimizer로, Relu나 LeakyRelu 활성화 함수를 사용하고 Dropout을 True로 줬을 때 성능이 좋았습니다.

# %%
for i,(name, train_val_dict) in enumerate(result_dict.items()):
    train_metric_dict = train_val_dict['train']
    val_metric_dict = train_val_dict['val']
    
    plt.figure(figsize=(10,8))
    plt.subplot(3,1,1)
    plt.plot(range(len(train_metric_dict['loss'])), train_metric_dict['loss'], label='train')

    x = [point[0] for point in val_metric_dict['loss']]
    y = [point[1] for point in val_metric_dict['loss']]

    plt.plot(x, y, linestyle='-', marker='o', markersize=5, color='red', label='test')
    plt.grid(alpha=0.3)
    plt.legend()
    plt.title("Train_loss vs Val_loss")

    plt.subplot(3,1,2)
    plt.plot(range(len(train_metric_dict['accuracy'])), train_metric_dict['accuracy'], label='train')

    x = [point[0] for point in val_metric_dict['accuracy']]
    y = [point[1] for point in val_metric_dict['accuracy']]

    plt.plot(x, y, linestyle='-', marker='o', markersize=5, color='red', label='test')  # s는 점의 크기
    plt.grid(alpha=0.3)
    plt.legend()
    plt.title("Train_accuracy vs Val_accuracy")

    plt.subplot(3,1,3)
    plt.plot(range(len(train_metric_dict['f1_score'])), train_metric_dict['f1_score'], label='train')

    x = [point[0] for point in val_metric_dict['f1_score']]
    y = [point[1] for point in val_metric_dict['f1_score']]

    plt.plot(x, y, linestyle='-', marker='o', markersize=5, color='red', label='test')
    plt.grid(alpha=0.3)
    plt.legend()
    plt.title("Train_f1 vs Val_f1")
    plt.suptitle(f"{i+1}/{len(result_dict)}{name}")
    plt.tight_layout()
    plt.show()
    print("-"* 15)
# Out:
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------

# %% [markdown]
# ## [MY CODE] Test Metric
#
# - test 데이터셋을 가지고 최종 metric을 찍어보았습니다.
#
# - val dataset과 비슷한 metric이 나온 것을 보니 훈련이 잘 된 것으로 판단이 되었습니다.

# %% [markdown]
# ## [LOG] Test Metric

# %%
test_dict = {}
for i,(name, train_val_dict) in enumerate(result_dict.items()):
  print(f"{i+1}/{len(result_dict)} Test Metric")
  model = train_val_dict['model']
  test_loss_lst = []
  test_preds_lst=[]
  test_labels_lst=[]
  for inputs, labels in dataloader_dict['test']:
      model.zero_grad()
      inputs, labels = inputs.to(device), labels.to(device).long() 
      with torch.no_grad():
          model.eval()
          preds = model(inputs)
      loss = criterion(preds, labels)
      preds_labels = torch.max(preds, dim=1).indices.detach().cpu().numpy()
      test_preds_lst.extend(preds_labels)
      labels = labels.detach().cpu().numpy()
      test_labels_lst.extend(labels)
      test_loss_lst.append(loss.item())
  accuracy = accuracy_score(test_preds_lst, test_labels_lst)
  f1 = f1_score(test_preds_lst, test_labels_lst, average='macro')
  test_loss = np.mean(test_loss_lst)

  print(f"Test | Loss: {test_loss:.3f} | Accuracy: {accuracy:.3f} | F1_Score: {f1:.3f}", end='\n\n')
  print("-"*15)
  test_dict[name] = {'loss': test_loss, 'accuracy': accuracy, 'f1_score': f1}
# Out:
# 1/12 Test Metric
# Test | Loss: 3.167 | Accuracy: 0.562 | F1_Score: 0.562
#
# ---------------
# 2/12 Test Metric
# Test | Loss: 1.748 | Accuracy: 0.393 | F1_Score: 0.382
#
# ---------------
# 3/12 Test Metric
# Test | Loss: 4.972 | Accuracy: 0.520 | F1_Score: 0.519
#
# ---------------
# 4/12 Test Metric
# Test | Loss: 1.741 | Accuracy: 0.394 | F1_Score: 0.382
#
# ---------------
# 5/12 Test Metric
# Test | Loss: 3.158 | Accuracy: 0.558 | F1_Score: 0.557
#
# ---------------
# 6/12 Test Metric
# Test | Loss: 1.744 | Accuracy: 0.388 | F1_Score: 0.375
#
# ---------------
# 7/12 Test Metric
# Test | Loss: 4.745 | Accuracy: 0.567 | F1_Score: 0.565
#
# ---------------
# 8/12 Test Metric
# Test | Loss: 1.748 | Accuracy: 0.386 | F1_Score: 0.376
#
# ---------------
# 9/12 Test Metric
# Test | Loss: 2.726 | Accuracy: 0.529 | F1_Score: 0.530
#
# ---------------
# 10/12 Test Metric
# Test | Loss: 2.250 | Accuracy: 0.219 | F1_Score: 0.155
#
# ---------------
# 11/12 Test Metric
# Test | Loss: 3.549 | Accuracy: 0.497 | F1_Score: 0.498
#
# ---------------
# 12/12 Test Metric
# Test | Loss: 2.245 | Accuracy: 0.216 | F1_Score: 0.144
#
# ---------------

# %%
index_lst = []
metric_lst = []
for name, value in test_dict.items():
    index_lst.append(name)
    metric_lst.append(value)
test_df = pd.DataFrame(metric_lst)
test_df.index = index_lst
test_df['case'] = test_df.index
test_df.index = range(len(test_df))
test_df
# Out:
#         loss  accuracy  f1_score  \
# 0   3.166706    0.5620  0.562101
# 1   1.747619    0.3930  0.381869
# 2   4.972142    0.5200  0.519208
# 3   1.741302    0.3940  0.381792
# 4   3.158050    0.5580  0.557151
# 5   1.743732    0.3875  0.375111
# 6   4.745032    0.5670  0.565183
# 7   1.748394    0.3860  0.375598
# 8   2.726417    0.5295  0.530446
# 9   2.250333    0.2190  0.154748
# 10  3.548521    0.4970  0.498254
# 11  2.244860    0.2160  0.144136
#
#                                              case
# 0                            (ReLU(), True, Adam)
# 1                             (ReLU(), True, SGD)
# 2                           (ReLU(), False, Adam)
# 3                            (ReLU(), False, SGD)
# 4    (LeakyReLU(negative_slope=0.01), True, Adam)
# 5     (LeakyReLU(negative_slope=0.01), True, SGD)
# 6   (LeakyReLU(negative_slope=0.01), False, Adam)
# 7    (LeakyReLU(negative_slope=0.01), False, SGD)
# 8                         (Sigmoid(), True, Adam)
# 9                          (Sigmoid(), True, SGD)
# 10                       (Sigmoid(), False, Adam)
# 11                        (Sigmoid(), False, SGD)

# %%
test_df.iloc[test_df['loss'].sort_values().index]
# Out:
#         loss  accuracy  f1_score  \
# 3   1.741302    0.3940  0.381792
# 5   1.743732    0.3875  0.375111
# 1   1.747619    0.3930  0.381869
# 7   1.748394    0.3860  0.375598
# 11  2.244860    0.2160  0.144136
# 9   2.250333    0.2190  0.154748
# 8   2.726417    0.5295  0.530446
# 4   3.158050    0.5580  0.557151
# 0   3.166706    0.5620  0.562101
# 10  3.548521    0.4970  0.498254
# 6   4.745032    0.5670  0.565183
# 2   4.972142    0.5200  0.519208
#
#                                              case
# 3                            (ReLU(), False, SGD)
# 5     (LeakyReLU(negative_slope=0.01), True, SGD)
# 1                             (ReLU(), True, SGD)
# 7    (LeakyReLU(negative_slope=0.01), False, SGD)
# 11                        (Sigmoid(), False, SGD)
# 9                          (Sigmoid(), True, SGD)
# 8                         (Sigmoid(), True, Adam)
# 4    (LeakyReLU(negative_slope=0.01), True, Adam)
# 0                            (ReLU(), True, Adam)
# 10                       (Sigmoid(), False, Adam)
# 6   (LeakyReLU(negative_slope=0.01), False, Adam)
# 2                           (ReLU(), False, Adam)

# %%
test_df.iloc[test_df['accuracy'].sort_values(ascending=False).index]
# Out:
#         loss  accuracy  f1_score  \
# 6   4.745032    0.5670  0.565183
# 0   3.166706    0.5620  0.562101
# 4   3.158050    0.5580  0.557151
# 8   2.726417    0.5295  0.530446
# 2   4.972142    0.5200  0.519208
# 10  3.548521    0.4970  0.498254
# 3   1.741302    0.3940  0.381792
# 1   1.747619    0.3930  0.381869
# 5   1.743732    0.3875  0.375111
# 7   1.748394    0.3860  0.375598
# 9   2.250333    0.2190  0.154748
# 11  2.244860    0.2160  0.144136
#
#                                              case
# 6   (LeakyReLU(negative_slope=0.01), False, Adam)
# 0                            (ReLU(), True, Adam)
# 4    (LeakyReLU(negative_slope=0.01), True, Adam)
# 8                         (Sigmoid(), True, Adam)
# 2                           (ReLU(), False, Adam)
# 10                       (Sigmoid(), False, Adam)
# 3                            (ReLU(), False, SGD)
# 1                             (ReLU(), True, SGD)
# 5     (LeakyReLU(negative_slope=0.01), True, SGD)
# 7    (LeakyReLU(negative_slope=0.01), False, SGD)
# 9                          (Sigmoid(), True, SGD)
# 11                        (Sigmoid(), False, SGD)

# %%
test_df.iloc[test_df['f1_score'].sort_values(ascending=False).index]
# Out:
#         loss  accuracy  f1_score  \
# 6   4.745032    0.5670  0.565183
# 0   3.166706    0.5620  0.562101
# 4   3.158050    0.5580  0.557151
# 8   2.726417    0.5295  0.530446
# 2   4.972142    0.5200  0.519208
# 10  3.548521    0.4970  0.498254
# 1   1.747619    0.3930  0.381869
# 3   1.741302    0.3940  0.381792
# 7   1.748394    0.3860  0.375598
# 5   1.743732    0.3875  0.375111
# 9   2.250333    0.2190  0.154748
# 11  2.244860    0.2160  0.144136
#
#                                              case
# 6   (LeakyReLU(negative_slope=0.01), False, Adam)
# 0                            (ReLU(), True, Adam)
# 4    (LeakyReLU(negative_slope=0.01), True, Adam)
# 8                         (Sigmoid(), True, Adam)
# 2                           (ReLU(), False, Adam)
# 10                       (Sigmoid(), False, Adam)
# 1                             (ReLU(), True, SGD)
# 3                            (ReLU(), False, SGD)
# 7    (LeakyReLU(negative_slope=0.01), False, SGD)
# 5     (LeakyReLU(negative_slope=0.01), True, SGD)
# 9                          (Sigmoid(), True, SGD)
# 11                        (Sigmoid(), False, SGD)

# %%
keyword = "True"
df_a = test_df[test_df['case'].apply(lambda x: True if keyword in str(x) else False)].reset_index(drop=True)

keyword = "False"
df_b = test_df[test_df['case'].apply(lambda x: True if keyword in str(x) else False)].reset_index(drop=True)

plt.figure(figsize=(8,6))

plt.subplot(3,1,1)
plt.plot(df_a['loss'], label = "Dropout True", color='blue')
plt.plot(df_b['loss'], label = "Dropout False", color='red')
plt.title(f"Standard: Dropout-loss")
plt.legend()

plt.subplot(3,1,2)
plt.plot(df_a['accuracy'], label = "Dropout True", color='blue')
plt.plot(df_b['accuracy'], label = "Dropout False", color='red')
plt.title(f"Standard: Dropout-accuracy")
plt.legend()

plt.subplot(3,1,3)
plt.plot(df_a['f1_score'], label = "Dropout True", color='blue')
plt.plot(df_b['f1_score'], label = "Dropout False", color='red')
plt.title(f"Standard: Dropout-f1")
plt.legend()

plt.tight_layout()
plt.show()

# %%
keyword = "Adam"
df_a = test_df[test_df['case'].apply(lambda x: True if keyword in str(x) else False)].reset_index(drop=True)

keyword = "SGD"
df_b = test_df[test_df['case'].apply(lambda x: True if keyword in str(x) else False)].reset_index(drop=True)

plt.figure(figsize=(8,6))

plt.subplot(3,1,1)
plt.plot(df_a['loss'], label = "Adam", color='blue')
plt.plot(df_b['loss'], label = "SGD", color='red')
plt.title(f"Standard: Adam vs SGD (loss)")
plt.legend()

plt.subplot(3,1,2)
plt.plot(df_a['accuracy'], label = "Adam", color='blue')
plt.plot(df_b['accuracy'], label = "SGD", color='red')
plt.title(f"Standard: Adam vs SGD (accuracy)")
plt.legend()

plt.subplot(3,1,3)
plt.plot(df_a['f1_score'], label = "Adam", color='blue')
plt.plot(df_b['f1_score'], label = "SGD", color='red')
plt.title(f"Standard: Adam vs SGD (f1)")
plt.legend()

plt.tight_layout()
plt.show()

# %%
keyword = "ReLU()"
df_a = test_df[test_df['case'].apply(lambda x: True if keyword in str(x) else False)].reset_index(drop=True)

keyword = "LeakyReLU"
df_b = test_df[test_df['case'].apply(lambda x: True if keyword in str(x) else False)].reset_index(drop=True)

keyword = "Sigmoid"
df_c = test_df[test_df['case'].apply(lambda x: True if keyword in str(x) else False)].reset_index(drop=True)

plt.figure(figsize=(8,6))

plt.subplot(3,1,1)
plt.plot(df_a['loss'], label = "ReLU()", color='blue')
plt.plot(df_b['loss'], label = "LeakyReLU", color='red')
plt.plot(df_c['loss'], label = "Sigmoid", color='green')
plt.title(f"Standard: Activation (loss)")
plt.legend()

plt.subplot(3,1,2)
plt.plot(df_a['accuracy'], label = "ReLU()", color='blue')
plt.plot(df_b['accuracy'], label = "LeakyReLU", color='red')
plt.plot(df_c['accuracy'], label = "Sigmoid", color='green')
plt.title(f"Standard: Activation(accuracy)")
plt.legend()

plt.subplot(3,1,3)
plt.plot(df_a['f1_score'], label = "ReLU()", color='blue')
plt.plot(df_b['f1_score'], label = "LeakyReLU", color='red')
plt.plot(df_c['f1_score'], label = "Sigmoid", color='green')
plt.title(f"Standard: Activation (f1)")
plt.legend()

plt.tight_layout()
plt.show()
